# %%
import pandas as pd
data = pd.read_csv('C:/Users/HP/sentiment analysis/sentiment result.csv', sep=',')

# %%
data
# Out:
#       Unnamed: 0                                             review    class  \
# 0              0  Up to this point I’ve mostly been using ChatGP...  positif
# 1              1  I’ve been a user since it’s initial roll out a...  positif
# 2              2  This app would almost be perfect if it wasn’t ...  positif
# 3              3  I recently downloaded the app and overall, it'...  positif
# 4              4  I appreciate the devs implementing Siri suppor...  positif
# ...          ...                                                ...      ...
# 2287        2287  This has to be a beginning to something crazy ...  positif
# 2288        2288  I’ve been using chat and have been a proud pre...  positif
# 2289        2289  The ChatGPT iOS app is an outstanding product....  positif
# 2290        2290  Sam Altman’s blatant attempt at regulatory cap...  negatif
# 2291        2291                                                  .  positif
#
#       result_svm
# 0              1
# ...

# %%
data.result_svm.unique()
data_list = [1]
data_neg = [-1]
data_net = [0]

# %%
datapos = data[data.result_svm.isin(data_list)]
datapos
# Out:
#       Unnamed: 0                                             review    class  \
# 0              0  Up to this point I’ve mostly been using ChatGP...  positif
# 1              1  I’ve been a user since it’s initial roll out a...  positif
# 2              2  This app would almost be perfect if it wasn’t ...  positif
# 3              3  I recently downloaded the app and overall, it'...  positif
# 4              4  I appreciate the devs implementing Siri suppor...  positif
# ...          ...                                                ...      ...
# 2286        2286  come to https://www.chatchat.bio, for free tri...  positif
# 2287        2287  This has to be a beginning to something crazy ...  positif
# 2288        2288  I’ve been using chat and have been a proud pre...  positif
# 2289        2289  The ChatGPT iOS app is an outstanding product....  positif
# 2291        2291                                                  .  positif
#
#       result_svm
# 0              1
# ...

# %%
datapos.to_csv('C:/Users/HP/sentiment analysis/review_chatgpt_positif.csv', sep=';')

# %%
dataneg = data[data.result_svm.isin(data_neg)]
dataneg
# Out:
#       Unnamed: 0                                             review    class  \
# 114          114  1.\t Chat GPT is a highly advanced artificial ...  negatif
# 150          150  If already handled by y’all cause a pretty big...  negatif
# 163          163  once you download the app, you have to submit ...  negatif
# 204          204  Sometimes when you ask it to generate somethin...  negatif
# 285          285  I used Apple to subscribe to the plus membersh...  negatif
# ...          ...                                                ...      ...
# 2268        2268  I’m trying to log in but I didn’t send my code...  negatif
# 2272        2272  Beware!!! This app requires personal info to u...  negatif
# 2275        2275  Installed 5/19/23. Locks up & crashes. Re-inst...  negatif
# 2279        2279  Had a working account previously before app an...  negatif
# 2290        2290  Sam Altman’s blatant attempt at regulatory cap...  negatif
#
#       result_svm
# 114           -1
# ...

# %%
from matplotlib import pyplot as plt

# %%
from wordcloud import WordCloud
text = " ".join(i for i in dataneg.review)
wordcloud = WordCloud( background_color="black").generate(text)
plt.figure( figsize=(10,7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
pos = datapos['review']

# %%
pos
# Out:
# 0       Up to this point I’ve mostly been using ChatGP...
# 1       I’ve been a user since it’s initial roll out a...
# 2       This app would almost be perfect if it wasn’t ...
# 3       I recently downloaded the app and overall, it'...
# 4       I appreciate the devs implementing Siri suppor...
#                               ...
# 2286    come to https://www.chatchat.bio, for free tri...
# 2287    This has to be a beginning to something crazy ...
# 2288    I’ve been using chat and have been a proud pre...
# 2289    The ChatGPT iOS app is an outstanding product....
# 2291                                                    .
# Name: review, Length: 1975, dtype: object

# %%
pos.to_csv('C:/Users/HP/sentiment analysis/result_chatgpt_.csv', sep=';')

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
text = " ".join(i for i in datapos.review)
wordcloud = WordCloud( background_color="black").generate(text)
plt.figure( figsize=(10,7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
datanet = data[data.result_svm.isin(data_net)]
datanet
# Out:
#       Unnamed: 0                                             review   class  \
# 988          988                                     Please improve  netral
# 1421        1421                                             Please  netral
# 1508        1508                                             Please  netral
# 1687        1687                                            Please！  netral
# 1729        1729                                            Please.  netral
# 1771        1771                       it makes my phone hot fix it  netral
# 1805        1805                                     Please fix it!  netral
# 1815        1815                                         4.0 please  netral
# 1875        1875                                                 Ok  netral
# 2047        2047  نسخة تحتاج التطوير ،، نسخة الموقع افضل بكثير م...  netral
# 2071        2071                                         تطبيق عادي  netral
# ...

# %%
datapos.to_csv('C:/Users/HP/Tug_svm_netral.csv', sep=';')

# %%
from wordcloud import WordCloud
text = " ".join(i for i in datanet.review)
wordcloud = WordCloud( background_color="black").generate(text)
plt.figure( figsize=(10,7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
